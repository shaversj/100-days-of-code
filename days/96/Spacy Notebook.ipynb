# %%
import sqlite3
import spacy
import pandas as pd

conn = sqlite3.connect('podcast_data.sqlite')
c = conn.cursor()
df = pd.read_sql_query("select * from podcast where podcast='1'", conn)

# %%
df['content'][50]
# Out:
# "Yeah. I totally agree. It's definitely a good sign that some of these closed source companies especially Microsoft are widely used is moving- I think they are learning a lot form Python and OpenSource. So it sounds like there is a lot of interesting pieces that you are bringing into Eve, like Cerberus and Flask Sentilen, things like that. Those are separate projects, separate packages that you are just using in Eve, right?"

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(df['content'][50])

# %%
tokens = [token for token in doc]
print(tokens)
# Out:
# [Yeah, ., I, totally, agree, ., It, 's, definitely, a, good, sign, that, some, of, these, closed, source, companies, especially, Microsoft, are, widely, used, is, moving-, I, think, they, are, learning, a, lot, form, Python, and, OpenSource, ., So, it, sounds, like, there, is, a, lot, of, interesting, pieces, that, you, are, bringing, into, Eve, ,, like, Cerberus, and, Flask, Sentilen, ,, things, like, that, ., Those, are, separate, projects, ,, separate, packages, that, you, are, just, using, in, Eve, ,, right, ?]

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.is_alpha, token.is_stop)
# Out:
# Yeah yeah INTJ UH ROOT Xxxx True False
# . . PUNCT . punct . False False
# I -PRON- PRON PRP nsubj X True False
# totally totally ADV RB advmod xxxx True False
# agree agree VERB VBP ROOT xxxx True False
# . . PUNCT . punct . False False
# It -PRON- PRON PRP nsubj Xx True False
# 's be VERB VBZ ROOT 'x False False
# definitely definitely ADV RB advmod xxxx True False
# a a DET DT det x True True
# good good ADJ JJ amod xxxx True False
# sign sign NOUN NN attr xxxx True False
# that that ADP IN mark xxxx True True
# some some DET DT nsubjpass xxxx True True
# of of ADP IN prep xx True True
# these these DET DT det xxxx True True
# closed closed ADJ JJ amod xxxx True False
# source source NOUN NN compound xxxx True False
# companies company NOUN NNS pobj xxxx True False
# especially especially ADV RB advmod xxxx True False
# Microsoft microsoft PROPN NNP nsubjpass Xxxxx True False
# are be VERB VBP auxpass xxx True True
# widely widely ADV RB advmod xxxx True False
# ...

# %%
spacy.displacy.render(doc, style='dep', jupyter=True, options={'distance': 70})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="213-0" class="displacy" width="5230" height="487.0" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Yeah.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="120">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="120">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">totally</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">ADV</tspan>
# ...
